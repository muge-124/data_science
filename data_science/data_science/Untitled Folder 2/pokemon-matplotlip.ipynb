# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("pokemon.csv")

# %%
#line plot
data.Speed.plot(kind ='line', color='g', label="Speed",linewidth=1 , alpha =0.5,grid=True ,linestyle =':')
data.Defense.plot(color ='r',label="Defense",linewidth=1 , alpha =0.5,grid=True ,linestyle ='-.')
plt.legend(loc='upper right') #bu satır çizilenler şeylerin sayfada nerde gözüktüğünü ifade eder
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('line plot')
plt.show()

# %%
#scatter plot (ili tane feature arasındaki correlationu bulmak)
data.plot(kind='scatter',x='Attack',y='Defense',alpha =0.5,color='red')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.title('Attack Defense Scatter Plot')
plt.show()

# %%
#histogram grafiği
data.Speed.plot(kind='hist',bins=50, figsize=(15,15))
plt.show()

# %%
data.Speed.plot(kind='hist',bins=50, figsize=(15,15))
plt.clf() #clf methodu clear eder grafiği
